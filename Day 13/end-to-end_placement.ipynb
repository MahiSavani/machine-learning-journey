# %% [markdown]
# # Steps
#
#  0. Preprocess + EDA + Feature Selection
#  1. Extract input and output cols
#  2. Scale the values
#  3. Train test split
#  4. Train the model
#  5. Evaluate the model/model selection
#  6. Deploy the model

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.4  117.0          1
# 1           1   4.8   82.0          0
# 2           2   6.9   56.0          1
# 3           3   7.1  104.0          1
# 4           4   3.8  121.0          0

# %%
df = df.iloc[:,1:]

# %%
df.shape
# Out:
# (150, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       150 non-null    float64
#  1   iq         150 non-null    float64
#  2   placement  150 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 3.6 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])
plt.legend(['Not Placed', 'Placed'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.show()

# %% [markdown]
# Here we are choosing logistic regression algorithm because we can see that data can be clearly devided into two sub-categories through an invisible line

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#      cgpa     iq
# 0     6.4  117.0
# 1     4.8   82.0
# 2     6.9   56.0
# 3     7.1  104.0
# 4     3.8  121.0
# ..    ...    ...
# 145   5.5  130.0
# 146   5.3  135.0
# 147   5.8  108.0
# 148   7.2   53.0
# 149   6.2  136.0
#
# [150 rows x 2 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 145    0
# 146    0
# 147    0
# 148    1
# 149    1
# Name: placement, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = 
x_train = scaler.fit_transform(x_train)
# Out:
#   Cell In[41], line 3
#     scaler =
#              ^
# SyntaxError: invalid syntax
